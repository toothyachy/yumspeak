# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim.utils import simple_preprocess

# %%
import string
import pickle
import re

# %% [markdown]
# ## Data Prep

# %%
merged_df = pd.read_csv('output/responses/merged_dataset.csv', low_memory=False)

# %%
restaurants_and_reviews = merged_df.copy()

# %%
restaurant_reviews = restaurants_and_reviews.filter(items=['name', 'main_rating',
       'address', 'link', 'review_photos', 'cuisine', 'latitude', 'longtitude', 'review_text'])

# %%
combined_reviews = restaurant_reviews.groupby(['name', 'main_rating', 'address', 'link', 'review_photos', 'cuisine',
       'latitude', 'longtitude'])['review_text'].apply(list).reset_index()

# %%
combined_reviews.iloc[0]['review_text']
# Out:
# ['Absolutely delicious Indian non-veg set with a very generous portion. Service was friendly, fast and efficient. Redeemed a MealPal lunch, super experience here   only restaurant so far with a QR code displayed prominently.',
#  'The food was much better than I had before.  The curries were less spicy as I expected it to be a little more spicy. The naan I must say is probably one of the best I have had. Thin and chewy with a light crispy finish. Can be very packed during lunch time.',
#  'Pretty good bistro bar',
#  'Nice good food and good vibe.',
#  'Good food, excellent vibe, reasonable prices, friendly service.',
#  'Had a great evening with friends, friendly staff and tasty food.',
#  'the Ideal place for a good Indian lunch set in CBD. Value for money and taste.',
#  'Reasonably priced meals and drinks make it an excellent venue for social gatherings. From 12 p.m. till midnight, happy hours are in effect  To give you an idea of the prices, ,as of March 2024, a pint of Sapporo costs $12, while a double is $20. Enjoying drinks while sitting outside was enjoyable, but the temperature is high and muggy, so ceiling fans and a cooler are needed. Their menu will astound you with the variety of food offered, like burgers, pizza, spaghetti, nan, and other typical Indian food.',
#  'Great experience, good food, awesome melodies.',
#  'Vegetarian options: Has a variety of vegetarian options Food',
#  'Very nice north Indian food. Specially lunch meal',
#  'Smallish place, a bit crammed seating.Lots of options on the menu and food tastes really good. Service is fast as well!',
#  'Just food food food to taste to feel better fulfilled Parking: Street parking , plan and reach early Food : 5/5 |',
#  'Tasty Food, courteous staff, value for money. Highly Recommended. You get Veg or Non-Veg plate for SGD 10, they also serve a number of Indian street food items like chat etc. Vegetarian options: You get Vegetarian plate with roti, Sabzi, Rice with choice of drink, I took Jaljira  which was great!  Vegetable Biryani, with Rayta and Papad is also great.',
#  'Expensive but tasty',
#  'Food is very tasty, they serve most of the alcoholic drinks like beer,whisky or wine. Food is good especially Indian',
#  'I have ordered chicken fried rice here. Food was to the point. Right level of spice and great vibe of boat quay',
#  'Place to grab the nice naan and chicken masala',
#  'Best chicken rice ever ate',
#  'Been here three times to watch IPL playoff and Finals. Food was really good. Have all the Indian snacks and dishes. My favorite is the Paani Poori shots. Must try. Food : 5/5',
#  'Excellent food and Good service. They also have alcohol options.',
#  'Always my go to place  for good food and even more good service',
#  'Nice place and you can enjoy tasty food specially u r indian. Excellent service and hygiene. Food',
#  'Really good food and reasonably priced drinks. Staff was super friendly too',
#  'Awesome Beer night and food...',
#  'Great tasting food with prompt and good service. Nice place for an evening with Friends.',
#  'Nice place, quality indian food.',
#  'Great location in vibrant circular road at Boat Quay all with great food, excellent and speedy service, and some good ales!',
#  'This Restaurant has lots of vegetarian options and cost wise is very reasonable. We tried the Arrabita Pasta and Paneer tikka wrap which was delicious and vast portion size. Met with the owner there who hails for India who gave us Great service on Singapore food options and travelling and shopping. Overall great place to have for lunch, dinner or even for snacks.',
#  'One of best Bar + restaurants in Boat Quay. The food hygiene, taste and service are excellent and the price seems reasonable considering the high  quality of food and service. One of few places where i never faced disappointment despite visiting quite often. Great work & kudos to the team running and operating the restaurant. Keep up the good work. Vegetarian options: Veggie Nachos, Masala fries, Masala peanut are my favourites',
#  'Good',
#  'I believe this is the best Indian restaurant we ever had in Singapore so far. We came here 3 times for the last 3 days before leaving Singapore. I would recommend the chicken tikka masala, roghan gosh, grilled salmon. The staff are super friendly and we don t want to name anyone since all of them served us well.',
#  'Really nice place to hangout.',
#  'Great food for the price! He makes sure everyone gets the high quality of food. Love to see someone is enthusiastic about their work quality']

# %% [markdown]
# ### Ignore below

# %%
# Remove numbers
combined_reviews['review_text_processed'] = combined_reviews['review_text'].apply(
    lambda reviews: [''.join(char for char in review if not char.isdigit()) for review in reviews]
)

# %%
combined_reviews.iloc[0]['review_text_processed']
# Out:
# ['Absolutely delicious Indian non-veg set with a very generous portion. Service was friendly, fast and efficient. Redeemed a MealPal lunch, super experience here   only restaurant so far with a QR code displayed prominently.',
#  'The food was much better than I had before.  The curries were less spicy as I expected it to be a little more spicy. The naan I must say is probably one of the best I have had. Thin and chewy with a light crispy finish. Can be very packed during lunch time.',
#  'Pretty good bistro bar',
#  'Nice good food and good vibe.',
#  'Good food, excellent vibe, reasonable prices, friendly service.',
#  'Had a great evening with friends, friendly staff and tasty food.',
#  'the Ideal place for a good Indian lunch set in CBD. Value for money and taste.',
#  'Reasonably priced meals and drinks make it an excellent venue for social gatherings. From  p.m. till midnight, happy hours are in effect  To give you an idea of the prices, ,as of March , a pint of Sapporo costs $, while a double is $. Enjoying drinks while sitting outside was enjoyable, but the temperature is high and muggy, so ceiling fans and a cooler are needed. Their menu will astound you with the variety of food offered, like burgers, pizza, spaghetti, nan, and other typical Indian food.',
#  'Great experience, good food, awesome melodies.',
#  'Vegetarian options: Has a variety of vegetarian options Food',
#  'Very nice north Indian food. Specially lunch meal',
#  'Smallish place, a bit crammed seating.Lots of options on the menu and food tastes really good. Service is fast as well!',
#  'Just food food food to taste to feel better fulfilled Parking: Street parking , plan and reach early Food : / |',
#  'Tasty Food, courteous staff, value for money. Highly Recommended. You get Veg or Non-Veg plate for SGD , they also serve a number of Indian street food items like chat etc. Vegetarian options: You get Vegetarian plate with roti, Sabzi, Rice with choice of drink, I took Jaljira  which was great!  Vegetable Biryani, with Rayta and Papad is also great.',
#  'Expensive but tasty',
#  'Food is very tasty, they serve most of the alcoholic drinks like beer,whisky or wine. Food is good especially Indian',
#  'I have ordered chicken fried rice here. Food was to the point. Right level of spice and great vibe of boat quay',
#  'Place to grab the nice naan and chicken masala',
#  'Best chicken rice ever ate',
#  'Been here three times to watch IPL playoff and Finals. Food was really good. Have all the Indian snacks and dishes. My favorite is the Paani Poori shots. Must try. Food : /',
#  'Excellent food and Good service. They also have alcohol options.',
#  'Always my go to place  for good food and even more good service',
#  'Nice place and you can enjoy tasty food specially u r indian. Excellent service and hygiene. Food',
#  'Really good food and reasonably priced drinks. Staff was super friendly too',
#  'Awesome Beer night and food...',
#  'Great tasting food with prompt and good service. Nice place for an evening with Friends.',
#  'Nice place, quality indian food.',
#  'Great location in vibrant circular road at Boat Quay all with great food, excellent and speedy service, and some good ales!',
#  'This Restaurant has lots of vegetarian options and cost wise is very reasonable. We tried the Arrabita Pasta and Paneer tikka wrap which was delicious and vast portion size. Met with the owner there who hails for India who gave us Great service on Singapore food options and travelling and shopping. Overall great place to have for lunch, dinner or even for snacks.',
#  'One of best Bar + restaurants in Boat Quay. The food hygiene, taste and service are excellent and the price seems reasonable considering the high  quality of food and service. One of few places where i never faced disappointment despite visiting quite often. Great work & kudos to the team running and operating the restaurant. Keep up the good work. Vegetarian options: Veggie Nachos, Masala fries, Masala peanut are my favourites',
#  'Good',
#  'I believe this is the best Indian restaurant we ever had in Singapore so far. We came here  times for the last  days before leaving Singapore. I would recommend the chicken tikka masala, roghan gosh, grilled salmon. The staff are super friendly and we don t want to name anyone since all of them served us well.',
#  'Really nice place to hangout.',
#  'Great food for the price! He makes sure everyone gets the high quality of food. Love to see someone is enthusiastic about their work quality']

# %%
# Remove punctuation by replacing it with spaces
def replace_punctuation_with_space(text):
    return text.translate(str.maketrans(string.punctuation, ' ' * len(string.punctuation)))

combined_reviews['review_text_processed'] = combined_reviews['review_text_processed'].apply(
    lambda reviews: [replace_punctuation_with_space(review) for review in reviews]
)

# %%
combined_reviews.iloc[0]['review_text_processed']
# Out:
# ['Absolutely delicious Indian non veg set with a very generous portion  Service was friendly  fast and efficient  Redeemed a MealPal lunch  super experience here   only restaurant so far with a QR code displayed prominently',
#  'The food was much better than I had before   The curries were less spicy as I expected it to be a little more spicy  The naan I must say is probably one of the best I have had  Thin and chewy with a light crispy finish  Can be very packed during lunch time',
#  'Pretty good bistro bar',
#  'Nice good food and good vibe',
#  'Good food  excellent vibe  reasonable prices  friendly service',
#  'Had a great evening with friends  friendly staff and tasty food',
#  'the Ideal place for a good Indian lunch set in CBD  Value for money and taste',
#  'Reasonably priced meals and drinks make it an excellent venue for social gatherings  From  p m  till midnight  happy hours are in effect  To give you an idea of the prices   as of March   a pint of Sapporo costs    while a double is    Enjoying drinks while sitting outside was enjoyable  but the temperature is high and muggy  so ceiling fans and a cooler are needed  Their menu will astound you with the variety of food offered  like burgers  pizza  spaghetti  nan  and other typical Indian food',
#  'Great experience  good food  awesome melodies',
#  'Vegetarian options  Has a variety of vegetarian options Food',
#  'Very nice north Indian food  Specially lunch meal',
#  'Smallish place  a bit crammed seating Lots of options on the menu and food tastes really good  Service is fast as well',
#  'Just food food food to taste to feel better fulfilled Parking  Street parking   plan and reach early Food',
#  'Tasty Food  courteous staff  value for money  Highly Recommended  You get Veg or Non Veg plate for SGD   they also serve a number of Indian street food items like chat etc  Vegetarian options  You get Vegetarian plate with roti  Sabzi  Rice with choice of drink  I took Jaljira  which was great   Vegetable Biryani  with Rayta and Papad is also great',
#  'Expensive but tasty',
#  'Food is very tasty  they serve most of the alcoholic drinks like beer whisky or wine  Food is good especially Indian',
#  'I have ordered chicken fried rice here  Food was to the point  Right level of spice and great vibe of boat quay',
#  'Place to grab the nice naan and chicken masala',
#  'Best chicken rice ever ate',
#  'Been here three times to watch IPL playoff and Finals  Food was really good  Have all the Indian snacks and dishes  My favorite is the Paani Poori shots  Must try  Food',
#  'Excellent food and Good service  They also have alcohol options',
#  'Always my go to place  for good food and even more good service',
#  'Nice place and you can enjoy tasty food specially u r indian  Excellent service and hygiene  Food',
#  'Really good food and reasonably priced drinks  Staff was super friendly too',
#  'Awesome Beer night and food',
#  'Great tasting food with prompt and good service  Nice place for an evening with Friends',
#  'Nice place  quality indian food',
#  'Great location in vibrant circular road at Boat Quay all with great food  excellent and speedy service  and some good ales',
#  'This Restaurant has lots of vegetarian options and cost wise is very reasonable  We tried the Arrabita Pasta and Paneer tikka wrap which was delicious and vast portion size  Met with the owner there who hails for India who gave us Great service on Singapore food options and travelling and shopping  Overall great place to have for lunch  dinner or even for snacks',
#  'One of best Bar   restaurants in Boat Quay  The food hygiene  taste and service are excellent and the price seems reasonable considering the high  quality of food and service  One of few places where i never faced disappointment despite visiting quite often  Great work   kudos to the team running and operating the restaurant  Keep up the good work  Vegetarian options  Veggie Nachos  Masala fries  Masala peanut are my favourites',
#  'Good',
#  'I believe this is the best Indian restaurant we ever had in Singapore so far  We came here  times for the last  days before leaving Singapore  I would recommend the chicken tikka masala  roghan gosh  grilled salmon  The staff are super friendly and we don t want to name anyone since all of them served us well',
#  'Really nice place to hangout',
#  'Great food for the price  He makes sure everyone gets the high quality of food  Love to see someone is enthusiastic about their work quality']

# %%
# Strip trailing spaces
combined_reviews['review_text_processed'] = combined_reviews['review_text_processed'].apply(
    lambda reviews: [review.strip() for review in reviews]
)

# %%
# Convert to lowercase and then tokenize each sentence
combined_reviews['review_text_processed'] = combined_reviews['review_text_processed'].apply(
    lambda reviews: [word_tokenize(review.lower()) for review in reviews]
)

# %%
combined_reviews.iloc[0]['review_text_processed']
# Out:
# [['absolutely',
#   'delicious',
#   'indian',
#   'non',
#   'veg',
#   'set',
#   'with',
#   'a',
#   'very',
#   'generous',
#   'portion',
#   'service',
#   'was',
#   'friendly',
#   'fast',
#   'and',
#   'efficient',
#   'redeemed',
#   'a',
#   'mealpal',
#   'lunch',
#   'super',
#   'experience',
#   'here',
#   'only',
#   'restaurant',
#   'so',
#   'far',
#   'with',
#   'a',
#   'qr',
#   'code',
#   'displayed',
#   'prominently'],
#  ['the',
#   'food',
#   'was',
#   'much',
#   'better',
#   'than',
#   'i',
#   'had',
#   'before',
#   'the',
#   'curries',
#   'were',
#   'less',
#   'spicy',
#   'as',
#   'i',
#   'expected',
#   'it',
#   'to',
#   'be',
#   'a',
#   'little',
#   'more',
#   'spicy',
#   'the',
#   'naan',
#   'i',
#   'must',
#   'say',
#   'is',
#   'probably',
#   'one',
#   'of',
#   'the',
#   'best',
#   'i',
#   'have',
#   'had',
#   'thin',
#   'and',
#   'chewy',
#   'with',
#   'a',
#   'light',
#   'crispy',
#   'finish',
#   'can',
#   'be',
#   'very',
#   'packed',
#   'during',
#   'lunch',
#   'time'],
#  ['pretty', 'good', 'bistro', 'bar'],
#  ['nice', 'good', 'food', 'and', 'good', 'vibe'],
#  ['good',
#   'food',
#   'excellent',
#   'vibe',
#   'reasonable',
#   'prices',
#   'friendly',
#   'service'],
#  ['had',
#   'a',
#   'great',
#   'evening',
#   'with',
#   'friends',
#   'friendly',
#   'staff',
#   'and',
#   'tasty',
#   'food'],
#  ['the',
#   'ideal',
#   'place',
#   'for',
#   'a',
#   'good',
#   'indian',
#   'lunch',
#   'set',
#   'in',
#   'cbd',
#   'value',
#   'for',
#   'money',
#   'and',
#   'taste'],
#  ['reasonably',
#   'priced',
#   'meals',
#   'and',
#   'drinks',
#   'make',
#   'it',
#   'an',
#   'excellent',
#   'venue',
#   'for',
#   'social',
#   'gatherings',
#   'from',
#   'p',
#   'm',
#   'till',
#   'midnight',
#   'happy',
#   'hours',
#   'are',
#   'in',
#   'effect',
#   'to',
#   'give',
#   'you',
#   'an',
#   'idea',
#   'of',
#   'the',
#   'prices',
#   'as',
#   'of',
#   'march',
#   'a',
#   'pint',
#   'of',
#   'sapporo',
#   'costs',
#   'while',
#   'a',
#   'double',
#   'is',
#   'enjoying',
#   'drinks',
#   'while',
#   'sitting',
#   'outside',
#   'was',
#   'enjoyable',
#   'but',
#   'the',
#   'temperature',
#   'is',
#   'high',
#   'and',
#   'muggy',
#   'so',
#   'ceiling',
#   'fans',
#   'and',
#   'a',
#   'cooler',
#   'are',
#   'needed',
#   'their',
#   'menu',
#   'will',
#   'astound',
#   'you',
#   'with',
#   'the',
#   'variety',
#   'of',
#   'food',
#   'offered',
#   'like',
#   'burgers',
#   'pizza',
#   'spaghetti',
#   'nan',
#   'and',
#   'other',
#   'typical',
#   'indian',
#   'food'],
#  ['great', 'experience', 'good', 'food', 'awesome', 'melodies'],
#  ['vegetarian',
#   'options',
#   'has',
#   'a',
#   'variety',
#   'of',
#   'vegetarian',
#   'options',
#   'food'],
#  ['very', 'nice', 'north', 'indian', 'food', 'specially', 'lunch', 'meal'],
#  ['smallish',
#   'place',
#   'a',
#   'bit',
#   'crammed',
#   'seating',
#   'lots',
#   'of',
#   'options',
#   'on',
#   'the',
#   'menu',
#   'and',
#   'food',
#   'tastes',
#   'really',
#   'good',
#   'service',
#   'is',
#   'fast',
#   'as',
#   'well'],
#  ['just',
#   'food',
#   'food',
#   'food',
#   'to',
#   'taste',
#   'to',
#   'feel',
#   'better',
#   'fulfilled',
#   'parking',
#   'street',
#   'parking',
#   'plan',
#   'and',
#   'reach',
#   'early',
#   'food'],
#  ['tasty',
#   'food',
#   'courteous',
#   'staff',
#   'value',
#   'for',
#   'money',
#   'highly',
#   'recommended',
#   'you',
#   'get',
#   'veg',
#   'or',
#   'non',
#   'veg',
#   'plate',
#   'for',
#   'sgd',
#   'they',
#   'also',
#   'serve',
#   'a',
#   'number',
#   'of',
#   'indian',
#   'street',
#   'food',
#   'items',
#   'like',
#   'chat',
#   'etc',
#   'vegetarian',
#   'options',
#   'you',
#   'get',
#   'vegetarian',
#   'plate',
#   'with',
#   'roti',
#   'sabzi',
#   'rice',
#   'with',
#   'choice',
#   'of',
#   'drink',
#   'i',
#   'took',
#   'jaljira',
#   'which',
#   'was',
#   'great',
#   'vegetable',
#   'biryani',
#   'with',
#   'rayta',
#   'and',
#   'papad',
#   'is',
#   'also',
#   'great'],
#  ['expensive', 'but', 'tasty'],
#  ['food',
#   'is',
#   'very',
#   'tasty',
#   'they',
#   'serve',
#   'most',
#   'of',
#   'the',
#   'alcoholic',
#   'drinks',
#   'like',
#   'beer',
#   'whisky',
#   'or',
#   'wine',
#   'food',
#   'is',
#   'good',
#   'especially',
#   'indian'],
#  ['i',
#   'have',
#   'ordered',
#   'chicken',
#   'fried',
#   'rice',
#   'here',
#   'food',
#   'was',
#   'to',
#   'the',
#   'point',
#   'right',
#   'level',
#   'of',
#   'spice',
#   'and',
#   'great',
#   'vibe',
#   'of',
#   'boat',
#   'quay'],
#  ['place', 'to', 'grab', 'the', 'nice', 'naan', 'and', 'chicken', 'masala'],
#  ['best', 'chicken', 'rice', 'ever', 'ate'],
#  ['been',
#   'here',
#   'three',
#   'times',
#   'to',
#   'watch',
#   'ipl',
#   'playoff',
#   'and',
#   'finals',
#   'food',
#   'was',
#   'really',
#   'good',
#   'have',
#   'all',
#   'the',
#   'indian',
#   'snacks',
#   'and',
#   'dishes',
#   'my',
#   'favorite',
#   'is',
#   'the',
#   'paani',
#   'poori',
#   'shots',
#   'must',
#   'try',
#   'food'],
#  ['excellent',
#   'food',
#   'and',
#   'good',
#   'service',
#   'they',
#   'also',
#   'have',
#   'alcohol',
#   'options'],
#  ['always',
#   'my',
#   'go',
#   'to',
#   'place',
#   'for',
#   'good',
#   'food',
#   'and',
#   'even',
#   'more',
#   'good',
#   'service'],
#  ['nice',
#   'place',
#   'and',
#   'you',
#   'can',
#   'enjoy',
#   'tasty',
#   'food',
#   'specially',
#   'u',
#   'r',
#   'indian',
#   'excellent',
#   'service',
#   'and',
#   'hygiene',
#   'food'],
#  ['really',
#   'good',
#   'food',
#   'and',
#   'reasonably',
#   'priced',
#   'drinks',
#   'staff',
#   'was',
#   'super',
#   'friendly',
#   'too'],
#  ['awesome', 'beer', 'night', 'and', 'food'],
#  ['great',
#   'tasting',
#   'food',
#   'with',
#   'prompt',
#   'and',
#   'good',
#   'service',
#   'nice',
#   'place',
#   'for',
#   'an',
#   'evening',
#   'with',
#   'friends'],
#  ['nice', 'place', 'quality', 'indian', 'food'],
#  ['great',
#   'location',
#   'in',
#   'vibrant',
#   'circular',
#   'road',
#   'at',
#   'boat',
#   'quay',
#   'all',
#   'with',
#   'great',
#   'food',
#   'excellent',
#   'and',
#   'speedy',
#   'service',
#   'and',
#   'some',
#   'good',
#   'ales'],
#  ['this',
#   'restaurant',
#   'has',
#   'lots',
#   'of',
#   'vegetarian',
#   'options',
#   'and',
#   'cost',
#   'wise',
#   'is',
#   'very',
#   'reasonable',
#   'we',
#   'tried',
#   'the',
#   'arrabita',
#   'pasta',
#   'and',
#   'paneer',
#   'tikka',
#   'wrap',
#   'which',
#   'was',
#   'delicious',
#   'and',
#   'vast',
#   'portion',
#   'size',
#   'met',
#   'with',
#   'the',
#   'owner',
#   'there',
#   'who',
#   'hails',
#   'for',
#   'india',
#   'who',
#   'gave',
#   'us',
#   'great',
#   'service',
#   'on',
#   'singapore',
#   'food',
#   'options',
#   'and',
#   'travelling',
#   'and',
#   'shopping',
#   'overall',
#   'great',
#   'place',
#   'to',
#   'have',
#   'for',
#   'lunch',
#   'dinner',
#   'or',
#   'even',
#   'for',
#   'snacks'],
#  ['one',
#   'of',
#   'best',
#   'bar',
#   'restaurants',
#   'in',
#   'boat',
#   'quay',
#   'the',
#   'food',
#   'hygiene',
#   'taste',
#   'and',
#   'service',
#   'are',
#   'excellent',
#   'and',
#   'the',
#   'price',
#   'seems',
#   'reasonable',
#   'considering',
#   'the',
#   'high',
#   'quality',
#   'of',
#   'food',
#   'and',
#   'service',
#   'one',
#   'of',
#   'few',
#   'places',
#   'where',
#   'i',
#   'never',
#   'faced',
#   'disappointment',
#   'despite',
#   'visiting',
#   'quite',
#   'often',
#   'great',
#   'work',
#   'kudos',
#   'to',
#   'the',
#   'team',
#   'running',
#   'and',
#   'operating',
#   'the',
#   'restaurant',
#   'keep',
#   'up',
#   'the',
#   'good',
#   'work',
#   'vegetarian',
#   'options',
#   'veggie',
#   'nachos',
#   'masala',
#   'fries',
#   'masala',
#   'peanut',
#   'are',
#   'my',
#   'favourites'],
#  ['good'],
#  ['i',
#   'believe',
#   'this',
#   'is',
#   'the',
#   'best',
#   'indian',
#   'restaurant',
#   'we',
#   'ever',
#   'had',
#   'in',
#   'singapore',
#   'so',
#   'far',
#   'we',
#   'came',
#   'here',
#   'times',
#   'for',
#   'the',
#   'last',
#   'days',
#   'before',
#   'leaving',
#   'singapore',
#   'i',
#   'would',
#   'recommend',
#   'the',
#   'chicken',
#   'tikka',
#   'masala',
#   'roghan',
#   'gosh',
#   'grilled',
#   'salmon',
#   'the',
#   'staff',
#   'are',
#   'super',
#   'friendly',
#   'and',
#   'we',
#   'don',
#   't',
#   'want',
#   'to',
#   'name',
#   'anyone',
#   'since',
#   'all',
#   'of',
#   'them',
#   'served',
#   'us',
#   'well'],
#  ['really', 'nice', 'place', 'to', 'hangout'],
#  ['great',
#   'food',
#   'for',
#   'the',
#   'price',
#   'he',
#   'makes',
#   'sure',
#   'everyone',
#   'gets',
#   'the',
#   'high',
#   'quality',
#   'of',
#   'food',
#   'love',
#   'to',
#   'see',
#   'someone',
#   'is',
#   'enthusiastic',
#   'about',
#   'their',
#   'work',
#   'quality']]

# %%
combined_reviews.iloc[2000]['review_text_processed']
# Out:
# ['really',
#  'good',
#  'food',
#  'good',
#  'service',
#  'out',
#  'of',
#  'this',
#  'world',
#  'was',
#  'a',
#  'pleasant',
#  'experience',
#  'thank',
#  'you',
#  'you',
#  'have',
#  'changed',
#  'my',
#  'life',
#  'food',
#  'was',
#  'good',
#  'especially',
#  'the',
#  'ultraman',
#  'chicken',
#  'fun',
#  'nice',
#  'and',
#  'worth',
#  'it',
#  'food',
#  'was',
#  'good',
#  'ultraman',
#  'chicken',
#  'was',
#  'good',
#  'ultra',
#  'man',
#  'chicken',
#  'was',
#  'damn',
#  'nice',
#  'worth',
#  'it',
#  'family',
#  'and',
#  'relaxed',
#  'ambience',
#  'parking',
#  'parking',
#  'is',
#  'not',
#  'an',
#  'issue',
#  'food',
#  'liver',
#  'porridge',
#  'fried',
#  'dumpling',
#  'are',
#  'good',
#  'hor',
#  'fun',
#  'has',
#  'wok',
#  'hei',
#  'but',
#  'a',
#  'bit',
#  'salty',
#  'perfect',
#  'venue',
#  'for',
#  'lunch',
#  'salted',
#  'egg',
#  'chicken',
#  'is',
#  'excellent',
#  'per',
#  'pax',
#  'all',
#  'ok',
#  'except',
#  'for',
#  'the',
#  'coffee',
#  'ribs',
#  'not',
#  'crispy',
#  'not',
#  'recommended',
#  'good',
#  'environment',
#  'nice',
#  'place',
#  'nice',
#  'food',
#  'value',
#  'for',
#  'money',
#  'very',
#  'delicious',
#  'came',
#  'here',
#  'for',
#  'a',
#  'department',
#  'lunch',
#  'food',
#  'was',
#  'the',
#  'traditional',
#  'chinese',
#  'fair',
#  'and',
#  'tasted',
#  'good',
#  'recommend',
#  'the',
#  'claypot',
#  'liver',
#  'curry',
#  'fish',
#  'head',
#  'ultraman',
#  'chicken',
#  'bbq',
#  'squid',
#  'and',
#  'green',
#  'dragon',
#  'beansprout',
#  'we',
#  'also',
#  'had',
#  'the',
#  'coffee',
#  'pork',
#  'rib',
#  'cereal',
#  'prawn',
#  'omelette',
#  'fuyong',
#  'and',
#  'salad',
#  'yutiow',
#  'which',
#  'were',
#  'ok',
#  'nice',
#  'ambience',
#  'and',
#  'good',
#  'for',
#  'large',
#  'gatherings',
#  'with',
#  'free',
#  'parking',
#  'located',
#  'within',
#  'the',
#  'compound',
#  'total',
#  'almost',
#  'for',
#  'about',
#  'of',
#  'us',
#  'foods',
#  'are',
#  'nice',
#  'big',
#  'servings',
#  'highly',
#  'recommended',
#  'the',
#  'food',
#  'was',
#  'awesome',
#  'and',
#  'the',
#  'service',
#  'was',
#  'remarkable',
#  'when',
#  'i',
#  'step',
#  'into',
#  'the',
#  'restaurant',
#  'it',
#  'had',
#  'the',
#  's',
#  'smell',
#  'cant',
#  'describe',
#  'but',
#  'reminded',
#  'me',
#  'of',
#  'those',
#  'typical',
#  's',
#  'restaurant',
#  'like',
#  'came',
#  'on',
#  'a',
#  'public',
#  'holiday',
#  'and',
#  'theres',
#  'no',
#  'crowd',
#  'kailan',
#  'was',
#  'so',
#  'so',
#  'good',
#  'with',
#  'rich',
#  'wok',
#  'hey',
#  'signature',
#  'curry',
#  'fish',
#  'head',
#  'rich',
#  'flavour',
#  'yet',
#  'not',
#  'too',
#  'spicy',
#  'and',
#  'having',
#  'fuzhu',
#  'soak',
#  'in',
#  'it',
#  'make',
#  'the',
#  'fuzhu',
#  'very',
#  'tasty',
#  'was',
#  'debone',
#  'with',
#  'abit',
#  'mixture',
#  'of',
#  'fats',
#  'n',
#  'meat',
#  'that',
#  'is',
#  'not',
#  'too',
#  'tough',
#  'n',
#  'abit',
#  'on',
#  'the',
#  'sweet',
#  'side',
#  'this',
#  'waa',
#  'a',
#  'bit',
#  'disappointed',
#  'especially',
#  'after',
#  'having',
#  'the',
#  'kailan',
#  'this',
#  'dish',
#  'dont',
#  'have',
#  'wok',
#  'hey',
#  'cant',
#  'feel',
#  'thr',
#  'caipo',
#  'and',
#  'was',
#  'surprise',
#  'that',
#  'its',
#  'on',
#  'the',
#  'sweet',
#  'side',
#  'too',
#  'good',
#  'food',
#  'and',
#  'good',
#  'service',
#  'usually',
#  'go',
#  'there',
#  'for',
#  'tzi',
#  'char',
#  'but',
#  'tried',
#  'dim',
#  'sum',
#  'and',
#  'it',
#  'was',
#  'better',
#  'than',
#  'expected',
#  'try',
#  'their',
#  'meat',
#  'ball',
#  'century',
#  'egg',
#  'congee',
#  'is',
#  'surprisingly',
#  'nice',
#  'good',
#  'place',
#  'curry',
#  'fish',
#  'head',
#  'was',
#  'nice',
#  'portion',
#  'was',
#  'a',
#  'bit',
#  'small',
#  'but',
#  'tasty',
#  'food',
#  'is',
#  'good',
#  'service',
#  'is',
#  'good',
#  'too',
#  'this',
#  'is',
#  'the',
#  'second',
#  'time',
#  'where',
#  'the',
#  'reservation',
#  'was',
#  'cancelled',
#  'last',
#  'minute',
#  'the',
#  'first',
#  'time',
#  'was',
#  'company',
#  's',
#  'lunch',
#  'where',
#  'reservation',
#  'was',
#  'made',
#  'weeks',
#  'ago',
#  'but',
#  'was',
#  'called',
#  'days',
#  'before',
#  'to',
#  'say',
#  'they',
#  'cant',
#  'accommodate',
#  'the',
#  'large',
#  'group',
#  'of',
#  'us',
#  'and',
#  'needed',
#  'us',
#  'to',
#  'be',
#  'seated',
#  'outside',
#  'instead',
#  'forcing',
#  'us',
#  'to',
#  'cancel',
#  'our',
#  'reservation',
#  'second',
#  'time',
#  'that',
#  'the',
#  'same',
#  'incident',
#  'happened',
#  'was',
#  'today',
#  's',
#  'family',
#  'dinner',
#  'will',
#  'not',
#  'come',
#  'back',
#  'again',
#  'went',
#  'during',
#  'lunch',
#  'coz',
#  'of',
#  'colleagues',
#  'recommendation',
#  'was',
#  'a',
#  'pleasant',
#  'surprise',
#  'delicious',
#  'zichar',
#  'tat',
#  'i',
#  'would',
#  'return',
#  'to',
#  'food',
#  'delicious',
#  'food',
#  'highly',
#  'recommended',
#  'food',
#  'nice',
#  'yummy',
#  'food',
#  'love',
#  'the',
#  'steam',
#  'ginger',
#  'chicken',
#  'the',
#  'best',
#  'parking',
#  'plenty',
#  'of',
#  'parking',
#  'lots',
#  'food',
#  'the',
#  'food',
#  'is',
#  'delicious',
#  'and',
#  'good',
#  'service',
#  'super',
#  'nice',
#  'food',
#  'what',
#  'an',
#  'interesting',
#  'place',
#  'which',
#  'brings',
#  'back',
#  'nostalgia',
#  'of',
#  'good',
#  'old',
#  'days',
#  'the',
#  'traditional',
#  'zi',
#  'char',
#  'offerings',
#  'are',
#  'stupendous',
#  'wide',
#  'range',
#  'of',
#  'choices',
#  'and',
#  'all',
#  'cook',
#  'to',
#  'perfection',
#  'i',
#  'loved',
#  'the',
#  'hei',
#  'chou',
#  'very',
#  'crispy',
#  'and',
#  'huge',
#  'the',
#  'specialty',
#  'salted',
#  'egg',
#  'chicken',
#  'was',
#  'very',
#  'good',
#  'too',
#  'the',
#  'salted',
#  'egg',
#  'flavoring',
#  'was',
#  'just',
#  'nice',
#  'to',
#  'bring',
#  'out',
#  'the',
#  'taste',
#  'of',
#  'the',
#  'chicken',
#  'hor',
#  'fun',
#  'came',
#  'with',
#  'wok',
#  'hei',
#  'and',
#  'the',
#  'noodles',
#  'are',
#  'tender',
#  'and',
#  'q',
#  'lastly',
#  'the',
#  'curry',
#  'fish',
#  'head',
#  'was',
#  'such',
#  'a',
#  'delight',
#  'the',
#  'manager',
#  'and',
#  'staff',
#  'are',
#  'also',
#  'very',
#  'prompt',
#  'in',
#  'responding',
#  'to',
#  'our',
#  'needs',
#  'indeed',
#  'a',
#  'great',
#  'place',
#  'to',
#  'enjoy',
#  'chinese',
#  'cuisine',
#  'with',
#  'wine',
#  'which',
#  'can',
#  'be',
#  'byob',
#  'would',
#  'definitely',
#  'come',
#  'back',
#  'again',
#  'consistently',
#  'good',
#  'food',
#  'and',
#  'great',
#  'service',
#  'and',
#  'love',
#  'the',
#  'vibes',
#  'of',
#  'their',
#  'outdoor',
#  'dining',
#  'space',
#  'we',
#  'ordered',
#  'truffle',
#  'pork',
#  'cuttlefish',
#  'kangkong',
#  'pork',
#  'liver',
#  'mee',
#  'sua',
#  'very',
#  'yummy',
#  'will',
#  'come',
#  'again',
#  'to',
#  'try',
#  'other',
#  'dishes',
#  'very',
#  'good',
#  'food',
#  'tasty',
#  'and',
#  'delicious',
#  'great',
#  'food',
#  'free',
#  'parking',
#  'everything',
#  'is',
#  'great',
#  'but',
#  'not',
#  'the',
#  'price',
#  'personally',
#  'i',
#  'feel',
#  'the',
#  'price',
#  'is',
#  'considered',
#  'expensive',
#  'for',
#  'the',
#  'local',
#  'nice',
#  'food',
#  'good',
#  'service',
#  'a',
#  'family',
#  'friendly',
#  'restaurant',
#  'amazing',
#  'food',
#  'and',
#  'service',
#  'tug',
#  'in',
#  'a',
#  'nice',
#  'undisturbed',
#  'corner',
#  'in',
#  'telok',
#  'blangah',
#  'the',
#  'service',
#  'is',
#  'good',
#  'free',
#  'parking',
#  'most',
#  'important',
#  'the',
#  'food',
#  'is',
#  'nice',
#  'service',
#  'at',
#  'reasonable',
#  'timeframe',
#  'it',
#  's',
#  'provide',
#  'affordable',
#  'pricing',
#  'at',
#  'a',
#  'reasonable',
#  'portion',
#  'for',
#  'a',
#  'family',
#  'of',
#  'rustic',
#  'old',
#  'place',
#  'that',
#  'serves',
#  'good',
#  'food',
#  'standards',
#  'have',
#  'dropped',
#  'a',
#  'little',
#  'but',
#  'still',
#  'live',
#  'the',
#  'ultraman',
#  'chicken',
#  'nice',
#  'food',
#  'and',
#  'will',
#  'definitely',
#  'come',
#  'again',
#  'good',
#  'good',
#  'egg',
#  'salted',
#  'chicken',
#  'although',
#  'not',
#  'very',
#  'creamy',
#  'sauce',
#  'chicken',
#  'was',
#  'juicy',
#  'yet',
#  'crispy',
#  'hotplate',
#  'tofu',
#  'was',
#  'sizzling',
#  'and',
#  'good',
#  'portioned',
#  'ordered',
#  'curry',
#  'fish',
#  'head',
#  'four',
#  'season',
#  'long',
#  'bean',
#  'and',
#  'coffee',
#  'pork',
#  'rib',
#  'all',
#  'is',
#  'very',
#  'nice',
#  'two',
#  'of',
#  'us',
#  'here',
#  'only',
#  'food',
#  'sum',
#  'kee',
#  'has',
#  'been',
#  'one',
#  'of',
#  'favourite',
#  'zichar',
#  'restaurant',
#  'in',
#  'sg',
#  'for',
#  'a',
#  'while',
#  'the',
#  'slight',
#  'con',
#  'is',
#  'that',
#  'the',
#  'location',
#  'is',
#  'slightly',
#  'inconvenient',
#  'without',
#  'a',
#  'car',
#  'we',
#  'arrived',
#  'at',
#  'pm',
#  'on',
#  'sunday',
#  'for',
#  'dinner',
#  'without',
#  'booking',
#  'and',
#  'was',
#  'lucky',
#  'to',
#  'grab',
#  'the',
#  'last',
#  'table',
#  'available',
#  'the',
#  'dishes',
#  'were',
#  'homey',
#  'flavourful',
#  'and',
#  'tasty',
#  'as',
#  'always',
#  'thumbs',
#  'up',
#  'great',
#  'curry',
#  'fishhead',
#  'and',
#  'ultraman',
#  'chicken',
#  'always',
#  'come',
#  'back',
#  'to',
#  'this',
#  'dish',
#  'the',
#  'food',
#  'is',
#  'awesome',
#  'first',
#  'time',
#  'here',
#  'and',
#  'we',
#  'finished',
#  'everything',
#  'on',
#  'our',
#  'plate',
#  'great',
#  'food',
#  'and',
#  'rustic',
#  'ambience',
#  'fish',
#  'head',
#  'curry',
#  'was',
#  'the',
#  'best',
#  'ive',
#  'had',
#  'in',
#  'a',
#  'while',
#  'must',
#  'try',
#  'the',
#  'iberico',
#  'ribs',
#  'too',
#  'always',
#  'love',
#  'the',
#  'food',
#  'here',
#  'of',
#  'the',
#  'worst',
#  'fishes',
#  'ive',
#  'ever',
#  'eaten',
#  'so',
#  'dry',
#  'and',
#  'has',
#  'a',
#  'very',
#  'strong',
#  'fishy',
#  'smell',
#  'and',
#  'the',
#  'fish',
#  'cost',
#  'food',
#  'very',
#  's',
#  'homely',
#  'restaurant',
#  'food',
#  'is',
#  'great',
#  'and',
#  'they',
#  'still',
#  'have',
#  'the',
#  'ultraman',
#  'chicken',
#  'from',
#  'way',
#  'back',
#  'good',
#  'food',
#  'will',
#  'come',
#  'back',
#  'again',
#  'went',
#  'there',
#  'for',
#  'farewell',
#  'lunch',
#  'it',
#  's',
#  'a',
#  'very',
#  'old',
#  'school',
#  'environment',
#  'with',
#  'free',
#  'parking',
#  'in',
#  'its',
#  'own',
#  'compound',
#  'the',
#  'dishes',
#  'were',
#  'promptly',
#  'served',
#  'love',
#  'the',
#  'salted',
#  'egg',
#  'chicken',
#  'ultra',
#  'man',
#  'french',
#  'beans',
#  'san',
#  'lou',
#  'hor',
#  'fun',
#  'will',
#  'definitely',
#  'go',
#  'back',
#  'again',
#  'food',
#  'old',
#  'school',
#  'quaint',
#  'place',
#  'but',
#  'good',
#  'food',
#  'must',
#  'try',
#  'the',
#  'salted',
#  'egg',
#  'chicken',
#  'and',
#  'fish',
#  'head',
#  'curry',
#  'loved',
#  'the',
#  'great',
#  'food',
#  'here',
#  'fav',
#  'dishes',
#  'curry',
#  'fish',
#  'head',
#  'ultraman',
#  'chicken',
#  'spinach',
#  'soup',
#  'ordered',
#  'dai',
#  'lok',
#  ...]

# %%
# Flatten the list
combined_reviews['review_text_processed'] = combined_reviews['review_text_processed'].apply(
    lambda reviews: [word for review in reviews for word in review]
)

# %%
# Set stop words
stop_words = set(stopwords.words('english'))

# %%
STOPWORDS = [('food', 407452),
 ('good', 248393),
 ('service', 217139),
 ('great', 138171),
 ('staff', 117568),
 ('nice', 110294),
 ('place', 108332),
 ('restaurant', 86786),
 ('dish', 84913),
 ('time', 78530),
 ('delicious', 78503),
 ('friendly', 73322),
 ('really', 72500),
 ('u', 66628),
 ('taste', 65326),
 ('also', 61263),
 ('experience', 61009),
 ('like', 60406),
 ('one', 57355),
 ('back', 56299)]

# %%
# Add our custom stopwords
custom_stopwords = set([word[0] for word in STOPWORDS])
stop_words.update(custom_stopwords)

# %%
# Remove stop words
combined_reviews['review_text_processed'] = combined_reviews['review_text_processed'].apply(lambda x: [w for w in x if not w in stop_words])

# %%
# Lemmatize
# lemmatizer = WordNetLemmatizer()
# combined_reviews['review_text_processed'] = combined_reviews['review_text_processed'].apply(lambda x: [lemmatizer.lemmatize(token) for token in x])

# %%
combined_reviews.iloc[2000]['review_text_processed']
# Out:
# ['world',
#  'pleasant',
#  'thank',
#  'changed',
#  'life',
#  'especially',
#  'ultraman',
#  'chicken',
#  'fun',
#  'worth',
#  'ultraman',
#  'chicken',
#  'ultra',
#  'man',
#  'chicken',
#  'damn',
#  'worth',
#  'family',
#  'relaxed',
#  'ambience',
#  'parking',
#  'parking',
#  'issue',
#  'liver',
#  'porridge',
#  'fried',
#  'dumpling',
#  'hor',
#  'fun',
#  'wok',
#  'hei',
#  'bit',
#  'salty',
#  'perfect',
#  'venue',
#  'lunch',
#  'salted',
#  'egg',
#  'chicken',
#  'excellent',
#  'per',
#  'pax',
#  'ok',
#  'except',
#  'coffee',
#  'ribs',
#  'crispy',
#  'recommended',
#  'environment',
#  'value',
#  'money',
#  'came',
#  'department',
#  'lunch',
#  'traditional',
#  'chinese',
#  'fair',
#  'tasted',
#  'recommend',
#  'claypot',
#  'liver',
#  'curry',
#  'fish',
#  'head',
#  'ultraman',
#  'chicken',
#  'bbq',
#  'squid',
#  'green',
#  'dragon',
#  'beansprout',
#  'coffee',
#  'pork',
#  'rib',
#  'cereal',
#  'prawn',
#  'omelette',
#  'fuyong',
#  'salad',
#  'yutiow',
#  'ok',
#  'ambience',
#  'large',
#  'gatherings',
#  'free',
#  'parking',
#  'located',
#  'within',
#  'compound',
#  'total',
#  'almost',
#  'us',
#  'foods',
#  'big',
#  'servings',
#  'highly',
#  'recommended',
#  'awesome',
#  'remarkable',
#  'step',
#  'smell',
#  'cant',
#  'describe',
#  'reminded',
#  'typical',
#  'came',
#  'public',
#  'holiday',
#  'theres',
#  'crowd',
#  'kailan',
#  'rich',
#  'wok',
#  'hey',
#  'signature',
#  'curry',
#  'fish',
#  'head',
#  'rich',
#  'flavour',
#  'yet',
#  'spicy',
#  'fuzhu',
#  'soak',
#  'make',
#  'fuzhu',
#  'tasty',
#  'debone',
#  'abit',
#  'mixture',
#  'fats',
#  'n',
#  'meat',
#  'tough',
#  'n',
#  'abit',
#  'sweet',
#  'side',
#  'waa',
#  'bit',
#  'disappointed',
#  'especially',
#  'kailan',
#  'dont',
#  'wok',
#  'hey',
#  'cant',
#  'feel',
#  'thr',
#  'caipo',
#  'surprise',
#  'sweet',
#  'side',
#  'usually',
#  'go',
#  'tzi',
#  'char',
#  'tried',
#  'dim',
#  'sum',
#  'better',
#  'expected',
#  'try',
#  'meat',
#  'ball',
#  'century',
#  'egg',
#  'congee',
#  'surprisingly',
#  'curry',
#  'fish',
#  'head',
#  'portion',
#  'bit',
#  'small',
#  'tasty',
#  'second',
#  'reservation',
#  'cancelled',
#  'last',
#  'minute',
#  'first',
#  'company',
#  'lunch',
#  'reservation',
#  'made',
#  'weeks',
#  'ago',
#  'called',
#  'days',
#  'say',
#  'cant',
#  'accommodate',
#  'large',
#  'group',
#  'us',
#  'needed',
#  'us',
#  'seated',
#  'outside',
#  'instead',
#  'forcing',
#  'us',
#  'cancel',
#  'reservation',
#  'second',
#  'incident',
#  'happened',
#  'today',
#  'family',
#  'dinner',
#  'come',
#  'went',
#  'lunch',
#  'coz',
#  'colleagues',
#  'recommendation',
#  'pleasant',
#  'surprise',
#  'zichar',
#  'tat',
#  'would',
#  'return',
#  'highly',
#  'recommended',
#  'yummy',
#  'love',
#  'steam',
#  'ginger',
#  'chicken',
#  'best',
#  'parking',
#  'plenty',
#  'parking',
#  'lots',
#  'super',
#  'interesting',
#  'brings',
#  'nostalgia',
#  'old',
#  'days',
#  'traditional',
#  'zi',
#  'char',
#  'offerings',
#  'stupendous',
#  'wide',
#  'range',
#  'choices',
#  'cook',
#  'perfection',
#  'loved',
#  'hei',
#  'chou',
#  'crispy',
#  'huge',
#  'specialty',
#  'salted',
#  'egg',
#  'chicken',
#  'salted',
#  'egg',
#  'flavoring',
#  'bring',
#  'chicken',
#  'hor',
#  'fun',
#  'came',
#  'wok',
#  'hei',
#  'noodles',
#  'tender',
#  'q',
#  'lastly',
#  'curry',
#  'fish',
#  'head',
#  'delight',
#  'manager',
#  'prompt',
#  'responding',
#  'needs',
#  'indeed',
#  'enjoy',
#  'chinese',
#  'cuisine',
#  'wine',
#  'byob',
#  'would',
#  'definitely',
#  'come',
#  'consistently',
#  'love',
#  'vibes',
#  'outdoor',
#  'dining',
#  'space',
#  'ordered',
#  'truffle',
#  'pork',
#  'cuttlefish',
#  'kangkong',
#  'pork',
#  'liver',
#  'mee',
#  'sua',
#  'yummy',
#  'come',
#  'try',
#  'dishes',
#  'tasty',
#  'free',
#  'parking',
#  'everything',
#  'price',
#  'personally',
#  'feel',
#  'price',
#  'considered',
#  'expensive',
#  'local',
#  'family',
#  'amazing',
#  'tug',
#  'undisturbed',
#  'corner',
#  'telok',
#  'blangah',
#  'free',
#  'parking',
#  'important',
#  'reasonable',
#  'timeframe',
#  'provide',
#  'affordable',
#  'pricing',
#  'reasonable',
#  'portion',
#  'family',
#  'rustic',
#  'old',
#  'serves',
#  'standards',
#  'dropped',
#  'little',
#  'still',
#  'live',
#  'ultraman',
#  'chicken',
#  'definitely',
#  'come',
#  'egg',
#  'salted',
#  'chicken',
#  'although',
#  'creamy',
#  'sauce',
#  'chicken',
#  'juicy',
#  'yet',
#  'crispy',
#  'hotplate',
#  'tofu',
#  'sizzling',
#  'portioned',
#  'ordered',
#  'curry',
#  'fish',
#  'head',
#  'four',
#  'season',
#  'long',
#  'bean',
#  'coffee',
#  'pork',
#  'rib',
#  'two',
#  'us',
#  'sum',
#  'kee',
#  'favourite',
#  'zichar',
#  'sg',
#  'slight',
#  'con',
#  'location',
#  'slightly',
#  'inconvenient',
#  'without',
#  'car',
#  'arrived',
#  'pm',
#  'sunday',
#  'dinner',
#  'without',
#  'booking',
#  'lucky',
#  'grab',
#  'last',
#  'table',
#  'available',
#  'dishes',
#  'homey',
#  'flavourful',
#  'tasty',
#  'always',
#  'thumbs',
#  'curry',
#  'fishhead',
#  'ultraman',
#  'chicken',
#  'always',
#  'come',
#  'awesome',
#  'first',
#  'finished',
#  'everything',
#  'plate',
#  'rustic',
#  'ambience',
#  'fish',
#  'head',
#  'curry',
#  'best',
#  'ive',
#  'must',
#  'try',
#  'iberico',
#  'ribs',
#  'always',
#  'love',
#  'worst',
#  'fishes',
#  'ive',
#  'ever',
#  'eaten',
#  'dry',
#  'strong',
#  'fishy',
#  'smell',
#  'fish',
#  'cost',
#  'homely',
#  'still',
#  'ultraman',
#  'chicken',
#  'way',
#  'come',
#  'went',
#  'farewell',
#  'lunch',
#  'old',
#  'school',
#  'environment',
#  'free',
#  'parking',
#  'compound',
#  'dishes',
#  'promptly',
#  'served',
#  'love',
#  'salted',
#  'egg',
#  'chicken',
#  'ultra',
#  'man',
#  'french',
#  'beans',
#  'san',
#  'lou',
#  'hor',
#  'fun',
#  'definitely',
#  'go',
#  'old',
#  'school',
#  'quaint',
#  'must',
#  'try',
#  'salted',
#  'egg',
#  'chicken',
#  'fish',
#  'head',
#  'curry',
#  'loved',
#  'fav',
#  'dishes',
#  'curry',
#  'fish',
#  'head',
#  'ultraman',
#  'chicken',
#  'spinach',
#  'soup',
#  'ordered',
#  'dai',
#  'lok',
#  'mee',
#  'tasty',
#  'especially',
#  'pork',
#  'lard',
#  'pumpkin',
#  'tofu',
#  'better',
#  'served',
#  'fried',
#  'cai',
#  'poh',
#  'instead',
#  'minced',
#  'pork',
#  'ginger',
#  'sliced',
#  'fish',
#  'well',
#  'done',
#  'dessert',
#  'orh',
#  'ni',
#  'soft',
#  'touch',
#  'smooth',
#  'butter',
#  'portions',
#  'quite',
#  'substantial',
#  'value',
#  'money',
#  'clean',
#  'prompt',
#  'sweet',
#  'sour',
#  'pork',
#  'rib',
#  'tender',
#  'fried',
#  'tofu',
#  'skin',
#  'prawn',
#  'served',
#  'hot',
#  'crispy',
#  'mayo',
#  'sauce',
#  'side',
#  'yummy',
#  'better',
#  'places',
#  'im',
#  'willing',
#  'travel',
#  'east',
#  'patronising',
#  'old',
#  'superbowl',
#  'outlet',
#  'quality',
#  'always',
#  'every',
#  'visit',
#  'served',
#  'fast',
#  'excellent',
#  'curry',
#  'fish',
#  'head',
#  'tops',
#  'must',
#  'try',
#  'sure',
#  'prawn',
#  'name',
#  'must',
#  'try',
#  'check',
#  'photo',
#  'pumpkin',
#  'tofu',
#  'superb',
#  'chrysanthemum',
#  'chinese',
#  'tea',
#  'excellent',
#  'promptly',
#  'refills',
#  'jug',
#  'heavily',
#  'flavored',
#  'dishes',
#  'tad',
#  'salty',
#  'oily',
#  'side',
#  'requested',
#  'takeaway',
#  'leftover',
#  'fried',
#  'rice',
#  'gave',
#  'us',
#  'empty',
#  'box',
#  'plastic',
#  'bag',
#  'insisting',
#  'pack',
#  'rice',
#  'dont',
#  'charge',
#  'quite',
#  'cozy',
#  'popular',
#  'zi',
#  'char',
#  'situated',
#  'telok',
#  'blangah',
#  'jurong',
#  'think',
#  'quality',
#  'better',
#  'telok',
#  'blangah',
#  'signature',
#  'dishes',
#  'ultraman',
#  'chicken',
#  'beancurd',
#  'pumpkin',
#  'gravy',
#  'various',
#  'crab',
#  'dishes',
#  'salted',
#  'egg',
#  'crab',
#  'black',
#  'pepper',
#  'crab',
#  'chilli',
#  'crab',
#  'curry',
#  'fishhead',
#  'xia',
#  'cao',
#  'best',
#  'town',
#  'minced',
#  'meat',
#  'well',
#  'seasoned',
#  'chinese',
#  'spices',
#  'complemented',
#  'prawn',
#  'meat',
#  'chunks',
#  'offered',
#  'different',
#  'texture',
#  'price',
#  'wise',
#  'bit',
#  'higher',
#  'end',
#  'compare',
#  'restaurants',
#  'similar',
#  'setting',
#  'menu',
#  'offerings',
#  'come',
#  'usually',
#  'walk',
#  'feeling',
#  'satisfied',
#  'love',
#  'ultraman',
#  'chicken',
#  'kind',
#  'came',
#  'fast',
#  'curry',
#  'scrumptious',
#  'best',
#  'salted',
#  'egg',
#  'fried',
#  'chicken',
#  'comfortable',
#  'ordered',
#  'store',
#  'takeaway',
#  'wait',
#  'mins',
#  'dishes',
#  'keep',
#  'reminding',
#  'order',
#  'forgot',
#  'order',
#  'online',
#  'instead',
#  'take',
#  'away',
#  'came',
#  'lunch',
#  'everything',
#  'fast',
#  'found',
#  'ex',
#  'primary',
#  'schoolmate',
#  'natalie',
#  'daughter',
#  'owner',
#  'indoor',
#  'outdoor',
#  'seating',
#  'area',
#  'ave',
#  'dollars',
#  'per',
#  'pax',
#  'tried',
#  'yam',
#  'paste',
#  'fried',
#  'ice',
#  'cream',
#  'parking',
#  'parking',
#  'available',
#  'within',
#  'vicinity',
#  'reviews',
#  'however',
#  'turns',
#  'otherwise',
#  'ordered',
#  'fish',
#  'head',
#  'curry',
#  'seems',
#  'remove',
#  'scales',
#  'thoroughly',
#  'fish',
#  'maw',
#  'crab',
#  'soup',
#  'starchy',
#  'overpowered',
#  'hua',
#  'diao',
#  'jiu',
#  'yam',
#  'ring',
#  'cooked',
#  'space',
#  'allocated',
#  'table',
#  'cram',
#  'worth',
#  'effort',
#  'travel',
#  'way',
#  'east',
#  'kid',
#  'friendliness',
#  'see',
#  'lot',
#  'fish',
#  'fish',
#  'tank',
#  'edit',
#  'still',
#  'bad',
#  'came',
#  'dinner',
#  'woman',
#  'showed',
#  'us',
#  'completely',
#  'bare',
#  'table',
#  'cutlery',
#  'sauces',
#  'even',
#  'table',
#  'cloth',
#  'servers',
#  'proceeded',
#  'ignore',
#  'us',
#  'even',
#  'menu',
#  'provided',
#  'wave',
#  'excellent',
#  'quick',
#  'order',
#  'superman',
#  'chicken',
#  'gets',
#  'quite',
#  'popular',
#  'weekends',
#  'indoor',
#  'outdoor',
#  'seating',
#  'nostalgic',
#  'environment',
#  'reasonable',
#  'price',
#  'pricing',
#  'fish',
#  'head',
#  'curry',
#  'bit',
#  'expensive',
#  'easiest',
#  'reach',
#  'travel',
#  'public',
#  'transport',
#  'totally',
#  'worth',
#  'portions',
#  'right',
#  'flavours',
#  'excellent',
#  'personal',
#  'favourites',
#  'sambal',
#  'potato',
#  'leaves',
#  'ultraman',
#  'chicken',
#  'salted',
#  'egg',
#  'chicken',
#  'best',
#  'singapore',
#  'fault',
#  'dishes',
#  'definitely',
#  'worth',
#  'revisiting',
#  'parking',
#  'lots',
#  'parking',
#  'around',
#  'hidden',
#  'location',
#  'tucked',
#  'away',
#  'rundown',
#  'yeos',
#  'building',
#  'parking',
#  'free',
#  'set',
#  'atmosphere',
#  'reminds',
#  'informal',
#  'gathering',
#  'conducive',
#  'business',
#  'lunch',
#  'noisy',
#  'priced',
#  'reasonably',
#  'unconpromised',
#  'eat',
#  'lard',
#  'request',
#  'ordering',
#  'offbeat',
#  'basic',
#  'tze',
#  'char',
#  'old',
#  'world',
#  'charm',
#  'yesteryear',
#  'think',
#  'tarred',
#  'roads',
#  'potholes',
#  'abound',
#  'way',
#  'decent',
#  'selection',
#  'price',
#  'decent',
#  'overwhelmingly',
#  'better',
#  'expected',
#  'pumpkin',
#  'tofu',
#  'silky',
#  'right',
#  'level',
#  'saltiness',
#  'salted',
#  'egg',
#  'chicken',
#  'ultraman',
#  'chicken',
#  'dry',
#  'soggy',
#  'xo',
#  'horfun',
#  'right',
#  'amount',
#  'spiciness',
#  'fragrance',
#  'pork',
#  'knuckle',
#  'beehoon',
#  'tender',
#  'tho',
#  'mightve',
#  'tad',
#  'salty',
#  'best',
#  'share',
#  'eggs',
#  'veggie',
#  'decently',
#  'order',
#  'though',
#  'something',
#  'rave',
#  'must',
#  'order',
#  'overrated',
#  'disappointed',
#  'mom',
#  'birthday',
#  'lunch',
#  'pricey',
#  'siew',
#  'mai',
#  'pc',
#  'sets',
#  'pc',
#  'deep',
#  'fried',
#  'taro',
#  'pc',
#  'overlook',
#  'sets',
#  'price',
#  'steep',
#  'dim',
#  'sum',
#  'frozen',
#  'fresh',
#  'mom',
#  'said',
#  'market',
#  'siew',
#  'mai',
#  'better',
#  'chewy',
#  'pork',
#  'old',
#  'kangkong',
#  'crispy',
#  'tofu',
#  'floury',
#  'mash',
#  'potatoes',
#  'worst',
#  'serve',
#  'burnt',
#  'deep',
#  'fried',
#  'taro',
#  'rejected',
#  'poor',
#  'follow',
#  'oil',
#  'deep',
#  'fry',
#  'sotong',
#  'yu',
#  'tiao',
#  'black',
#  'soggy',
#  'mee',
#  'sua',
#  'pathetic',
#  'med',
#  'size',
#  'prawn',
#  ...]

# %% [markdown]
# ## Run Cells from Here Only!

# %%
# Set stop words
stop_words = set(stopwords.words('english'))
# Add our custom stopwords
STOPWORDS = [('food', 407452),
 ('good', 248393),
 ('service', 217139),
 ('great', 138171),
 ('staff', 117568),
 ('nice', 110294),
 ('place', 108332),
 ('restaurant', 86786),
 ('dish', 84913),
 ('time', 78530),
 ('delicious', 78503),
 ('friendly', 73322),
 ('really', 72500),
 ('u', 66628),
 ('taste', 65326),
 ('also', 61263),
 ('experience', 61009),
 ('like', 60406),
 ('one', 57355),
 ('back', 56299)]
custom_stopwords = set([word[0] for word in STOPWORDS])
stop_words.update(custom_stopwords)
    
def data_processing(df):
    # Remove numbers
    tokens = df['review_text'].apply(lambda reviews: [''.join(char for char in review if not char.isdigit()) for review in reviews])
    # Flatten the list
    tokens = [word for review in tokens for word in review]
    # Remove punctuation by replacing it with spaces
    pattern = re.compile(f"[{re.escape(string.punctuation)}]")
    tokens = [pattern.sub(' ', token) for token in tokens]
    # Strip trailing spaces
    tokens = [review.strip() for review in tokens]
    # Convert to lowercase and then tokenize each sentence
    tokens = [word_tokenize(review.lower()) for review in tokens]
    # Flatten the list
    tokens = [word for review in tokens for word in review]
    # Remove stop words
    tokens = [w for w in tokens if not w in stop_words]
    return tokens

# %%
tokens = data_processing(combined_reviews)

# %%
tokens
# Out:
# ['absolutely',
#  'indian',
#  'non',
#  'veg',
#  'set',
#  'generous',
#  'portion',
#  'fast',
#  'efficient',
#  'redeemed',
#  'mealpal',
#  'lunch',
#  'super',
#  'far',
#  'qr',
#  'code',
#  'displayed',
#  'prominently',
#  'much',
#  'better',
#  'curries',
#  'less',
#  'spicy',
#  'expected',
#  'little',
#  'spicy',
#  'naan',
#  'must',
#  'say',
#  'probably',
#  'best',
#  'thin',
#  'chewy',
#  'light',
#  'crispy',
#  'finish',
#  'packed',
#  'lunch',
#  'pretty',
#  'bistro',
#  'bar',
#  'vibe',
#  'excellent',
#  'vibe',
#  'reasonable',
#  'prices',
#  'evening',
#  'friends',
#  'tasty',
#  'ideal',
#  'indian',
#  'lunch',
#  'set',
#  'cbd',
#  'value',
#  'money',
#  'reasonably',
#  'priced',
#  'meals',
#  'drinks',
#  'make',
#  'excellent',
#  'venue',
#  'social',
#  'gatherings',
#  'p',
#  'till',
#  'midnight',
#  'happy',
#  'hours',
#  'effect',
#  'give',
#  'idea',
#  'prices',
#  'march',
#  'pint',
#  'sapporo',
#  'costs',
#  'double',
#  'enjoying',
#  'drinks',
#  'sitting',
#  'outside',
#  'enjoyable',
#  'temperature',
#  'high',
#  'muggy',
#  'ceiling',
#  'fans',
#  'cooler',
#  'needed',
#  'menu',
#  'astound',
#  'variety',
#  'offered',
#  'burgers',
#  'pizza',
#  'spaghetti',
#  'nan',
#  'typical',
#  'indian',
#  'awesome',
#  'melodies',
#  'vegetarian',
#  'options',
#  'variety',
#  'vegetarian',
#  'options',
#  'north',
#  'indian',
#  'specially',
#  'lunch',
#  'meal',
#  'smallish',
#  'bit',
#  'crammed',
#  'seating',
#  'lots',
#  'options',
#  'menu',
#  'tastes',
#  'fast',
#  'well',
#  'feel',
#  'better',
#  'fulfilled',
#  'parking',
#  'street',
#  'parking',
#  'plan',
#  'reach',
#  'early',
#  'tasty',
#  'courteous',
#  'value',
#  'money',
#  'highly',
#  'recommended',
#  'get',
#  'veg',
#  'non',
#  'veg',
#  'plate',
#  'sgd',
#  'serve',
#  'number',
#  'indian',
#  'street',
#  'items',
#  'chat',
#  'etc',
#  'vegetarian',
#  'options',
#  'get',
#  'vegetarian',
#  'plate',
#  'roti',
#  'sabzi',
#  'rice',
#  'choice',
#  'drink',
#  'took',
#  'jaljira',
#  'vegetable',
#  'biryani',
#  'rayta',
#  'papad',
#  'expensive',
#  'tasty',
#  'tasty',
#  'serve',
#  'alcoholic',
#  'drinks',
#  'beer',
#  'whisky',
#  'wine',
#  'especially',
#  'indian',
#  'ordered',
#  'chicken',
#  'fried',
#  'rice',
#  'point',
#  'right',
#  'level',
#  'spice',
#  'vibe',
#  'boat',
#  'quay',
#  'grab',
#  'naan',
#  'chicken',
#  'masala',
#  'best',
#  'chicken',
#  'rice',
#  'ever',
#  'ate',
#  'three',
#  'times',
#  'watch',
#  'ipl',
#  'playoff',
#  'finals',
#  'indian',
#  'snacks',
#  'dishes',
#  'favorite',
#  'paani',
#  'poori',
#  'shots',
#  'must',
#  'try',
#  'excellent',
#  'alcohol',
#  'options',
#  'always',
#  'go',
#  'even',
#  'enjoy',
#  'tasty',
#  'specially',
#  'r',
#  'indian',
#  'excellent',
#  'hygiene',
#  'reasonably',
#  'priced',
#  'drinks',
#  'super',
#  'awesome',
#  'beer',
#  'night',
#  'tasting',
#  'prompt',
#  'evening',
#  'friends',
#  'quality',
#  'indian',
#  'location',
#  'vibrant',
#  'circular',
#  'road',
#  'boat',
#  'quay',
#  'excellent',
#  'speedy',
#  'ales',
#  'lots',
#  'vegetarian',
#  'options',
#  'cost',
#  'wise',
#  'reasonable',
#  'tried',
#  'arrabita',
#  'pasta',
#  'paneer',
#  'tikka',
#  'wrap',
#  'vast',
#  'portion',
#  'size',
#  'met',
#  'owner',
#  'hails',
#  'india',
#  'gave',
#  'us',
#  'singapore',
#  'options',
#  'travelling',
#  'shopping',
#  'overall',
#  'lunch',
#  'dinner',
#  'even',
#  'snacks',
#  'best',
#  'bar',
#  'restaurants',
#  'boat',
#  'quay',
#  'hygiene',
#  'excellent',
#  'price',
#  'seems',
#  'reasonable',
#  'considering',
#  'high',
#  'quality',
#  'places',
#  'never',
#  'faced',
#  'disappointment',
#  'despite',
#  'visiting',
#  'quite',
#  'often',
#  'work',
#  'kudos',
#  'team',
#  'running',
#  'operating',
#  'keep',
#  'work',
#  'vegetarian',
#  'options',
#  'veggie',
#  'nachos',
#  'masala',
#  'fries',
#  'masala',
#  'peanut',
#  'favourites',
#  'believe',
#  'best',
#  'indian',
#  'ever',
#  'singapore',
#  'far',
#  'came',
#  'times',
#  'last',
#  'days',
#  'leaving',
#  'singapore',
#  'would',
#  'recommend',
#  'chicken',
#  'tikka',
#  'masala',
#  'roghan',
#  'gosh',
#  'grilled',
#  'salmon',
#  'super',
#  'want',
#  'name',
#  'anyone',
#  'since',
#  'served',
#  'us',
#  'well',
#  'hangout',
#  'price',
#  'makes',
#  'sure',
#  'everyone',
#  'gets',
#  'high',
#  'quality',
#  'love',
#  'see',
#  'someone',
#  'enthusiastic',
#  'work',
#  'quality',
#  'coffeeshkp',
#  'longer',
#  'already',
#  'take',
#  'note',
#  'hours',
#  'store',
#  'always',
#  'cheap',
#  'quality',
#  'served',
#  'frills',
#  'kimly',
#  'dim',
#  'sum',
#  'coffeeshop',
#  'everything',
#  'anymore',
#  'promotion',
#  'june',
#  'buy',
#  'get',
#  'free',
#  'avg',
#  'surely',
#  'worth',
#  'type',
#  'always',
#  'go',
#  'yam',
#  'ball',
#  'big',
#  'bao',
#  'porridge',
#  'high',
#  'cp',
#  'value',
#  'price',
#  'per',
#  'get',
#  'free',
#  'order',
#  'items',
#  'basically',
#  'value',
#  'exactly',
#  'paid',
#  'owner',
#  'pls',
#  'update',
#  'average',
#  'price',
#  'affordable',
#  'typical',
#  'coffee',
#  'shop',
#  'setting',
#  'mass',
#  'production',
#  'okay',
#  'acceptable',
#  'different',
#  'traditional',
#  'longer',
#  'dim',
#  'sum',
#  'cozy',
#  'kopitiam',
#  'simple',
#  'fuss',
#  'free',
#  'dim',
#  'sum',
#  'decent',
#  'pricing',
#  'per',
#  'value',
#  'free',
#  'every',
#  'purchased',
#  'get',
#  'dimsum',
#  'fixed',
#  'low',
#  'prices',
#  'definitely',
#  'yummy',
#  'affordable',
#  'famous',
#  'dimsum',
#  'chains',
#  'restaurants',
#  'used',
#  'risen',
#  'per',
#  'item',
#  'menu',
#  'extensive',
#  'steamed',
#  'fried',
#  'baos',
#  'options',
#  'love',
#  'stalls',
#  'decent',
#  'comfort',
#  'esp',
#  'noodles',
#  'store',
#  'super',
#  'comforting',
#  'dimsum',
#  'must',
#  'order',
#  'everytime',
#  'siew',
#  'mai',
#  'pork',
#  'century',
#  'egg',
#  'porridge',
#  'chicken',
#  'feet',
#  'pork',
#  'ribs',
#  'dabao',
#  'ccf',
#  'fried',
#  'yam',
#  'dumpling',
#  'take',
#  'prawn',
#  'sambal',
#  'liked',
#  'chili',
#  'super',
#  'shioks',
#  'fast',
#  'instant',
#  'upon',
#  'ordering',
#  'gets',
#  'reheated',
#  'served',
#  'almost',
#  'instantly',
#  'get',
#  'prepared',
#  'order',
#  'avoid',
#  'flustered',
#  'atmosphere',
#  'clean',
#  'area',
#  'airy',
#  'small',
#  'neighbourhood',
#  'hawker',
#  'cleaners',
#  'neighbourhood',
#  'goers',
#  'responsible',
#  'w',
#  'clearing',
#  'plates',
#  'keeping',
#  'area',
#  'cleaned',
#  'complains',
#  'area',
#  'parking',
#  'hdb',
#  'parking',
#  'available',
#  'however',
#  'prefer',
#  'park',
#  'near',
#  'hawker',
#  'lots',
#  'limited',
#  'due',
#  'tight',
#  'small',
#  'lanes',
#  'kid',
#  'friendliness',
#  'lots',
#  'neighbourhood',
#  'people',
#  'coming',
#  'small',
#  'hawkers',
#  'always',
#  'see',
#  'groups',
#  'family',
#  'esp',
#  'weekends',
#  'cheapest',
#  'think',
#  'dim',
#  'sum',
#  'available',
#  'please',
#  'dont',
#  'expect',
#  'quality',
#  'fair',
#  'enough',
#  'pricing',
#  'pay',
#  'cheap',
#  'thrill',
#  'still',
#  'come',
#  'things',
#  'include',
#  'steamed',
#  'yam',
#  'cake',
#  'xo',
#  'chilli',
#  'paste',
#  'kid',
#  'friendliness',
#  'kopi',
#  'tiam',
#  'kids',
#  'ok',
#  'cheap',
#  'reasonable',
#  'theres',
#  'dim',
#  'sum',
#  'dim',
#  'sum',
#  'indulging',
#  'delectable',
#  'dim',
#  'sum',
#  'unique',
#  'delightful',
#  'combination',
#  'flavorful',
#  'dim',
#  'sum',
#  'dishes',
#  'hot',
#  'porridge',
#  'century',
#  'egg',
#  'creates',
#  'savory',
#  'satisfying',
#  'meal',
#  'peaceful',
#  'quiet',
#  'atmosphere',
#  'adds',
#  'sense',
#  'tranquility',
#  'dining',
#  'allowing',
#  'enjoy',
#  'relaxed',
#  'setting',
#  'convenient',
#  'parking',
#  'right',
#  'front',
#  'shop',
#  'makes',
#  'easy',
#  'access',
#  'enjoy',
#  'culinary',
#  'gem',
#  'overall',
#  'dining',
#  'dim',
#  'sum',
#  'hot',
#  'porridge',
#  'century',
#  'egg',
#  'memorable',
#  'enjoyable',
#  'sure',
#  'leave',
#  'craving',
#  'attentive',
#  'pricing',
#  'change',
#  'dim',
#  'sum',
#  'total',
#  'spent',
#  'value',
#  'money',
#  'find',
#  'cheaper',
#  'dimsum',
#  'nearby',
#  'order',
#  'spoilt',
#  'choices',
#  'quality',
#  'unbelievably',
#  'wait',
#  'fifteen',
#  'minutes',
#  'siomai',
#  'long',
#  'poor',
#  'maybe',
#  'went',
#  'three',
#  'morning',
#  'dim',
#  'sum',
#  'quite',
#  'price',
#  'quite',
#  'reasonable',
#  'parking',
#  'quite',
#  'number',
#  'lots',
#  'lunch',
#  'crowd',
#  'kid',
#  'friendliness',
#  'hazards',
#  'wheelchair',
#  'accessibility',
#  'easy',
#  'carpark',
#  'coffeeshop',
#  'stars',
#  'stars',
#  'price',
#  'price',
#  'still',
#  'favorite',
#  'makan',
#  'visiting',
#  'past',
#  'years',
#  'regular',
#  'customer',
#  'since',
#  'opening',
#  'tonight',
#  'unpleasant',
#  'surprise',
#  'lo',
#  'mai',
#  'gai',
#  'spoilt',
#  'chao',
#  'sgn',
#  'feedback',
#  'tmr',
#  'n',
#  'see',
#  'say',
#  'coz',
#  'impossible',
#  'know',
#  'spoilt',
#  'whole',
#  'car',
#  'stink',
#  'driving',
#  'went',
#  'stall',
#  'n',
#  'inform',
#  'spoilt',
#  'lo',
#  'mai',
#  'gai',
#  'lady',
#  'promptly',
#  'replace',
#  'attitude',
#  'n',
#  'push',
#  'away',
#  'complaint',
#  'value',
#  'money',
#  'tasty',
#  'dim',
#  'sum',
#  'nothing',
#  'fancy',
#  'fuss',
#  'supper',
#  'dec',
#  'hrs',
#  'vietnamese',
#  'casher',
#  'rude',
#  'dunno',
#  'count',
#  'charge',
#  'plate',
#  'extra',
#  'refuse',
#  'admit',
#  'careful',
#  'order',
#  'variety',
#  'choices',
#  'choose',
#  'price',
#  'ordered',
#  'dishes',
#  'end',
#  'even',
#  'super',
#  'affordable',
#  'dim',
#  'sum',
#  'overall',
#  'average',
#  'compare',
#  'restaurants',
#  'level',
#  'cheapest',
#  'dim',
#  'sum',
#  'ever',
#  'complain',
#  'fast',
#  'prompt',
#  'hours',
#  'clean',
#  'coffeeshop',
#  'environment',
#  'oder',
#  'grab',
#  'lost',
#  'item',
#  'chee',
#  'cheong',
#  'fun',
#  'prawn',
#  'dim',
#  'sum',
#  'available',
#  'purple',
#  'mantou',
#  'big',
#  'bun',
#  'tasty',
#  'pcs',
#  'per',
#  'ok',
#  'ok',
#  'la',
#  'supper',
#  'seriously',
#  'missed',
#  'order',
#  'paid',
#  'gave',
#  'atrocious',
#  'twice',
#  'already',
#  'prices',
#  'reasonable',
#  'affordable',
#  'price',
#  'plate',
#  'still',
#  'worth',
#  'quality',
#  'n',
#  'clean',
#  'n',
#  'quiet',
#  'ambiance',
#  'love',
#  'kid',
#  'friendliness',
#  'many',
#  'kids',
#  'western',
#  'ban',
#  'mian',
#  'teochew',
#  'noodle',
#  'etc',
#  'eat',
#  'able',
#  'price',
#  'take',
#  'note',
#  'current',
#  'price',
#  'per',
#  'order',
#  'buy',
#  'get',
#  'free',
#  'average',
#  'per',
#  'order',
#  'dont',
#  'know',
#  'find',
#  'price',
#  'line',
#  'anywhere',
#  'else',
#  'hit',
#  'misses',
#  'ng',
#  'gok',
#  'red',
#  'bean',
#  'sesame',
#  'ball',
#  'generally',
#  'fried',
#  'items',
#  'century',
#  'egg',
#  'porridge',
#  'lots',
#  'ingredients',
#  'lacks',
#  'flavour',
#  'fixed',
#  'putting',
#  'soy',
#  'sauce',
#  'overall',
#  'affordable',
#  'dim',
#  'sum',
#  'coffeeshops',
#  'kopi',
#  'standard',
#  'buy',
#  'get',
#  'plate',
#  'free',
#  'per',
#  'plate',
#  'price',
#  'affordable',
#  'chicken',
#  'wing',
#  'wrapped',
#  'paper',
#  'fried',
#  'dim',
#  'sum',
#  'guy',
#  'serving',
#  'dishes',
#  'well',
#  'favourite',
#  'dim',
#  'sum',
#  'affordable',
#  'hrs',
#  'favourite',
#  'late',
#  'night',
#  'supper',
#  'go',
#  'updated',
#  'july',
#  'view',
#  'recent',
#  'price',
#  'hikes',
#  'everywhere',
#  'electricity',
#  'hikes',
#  'etc',
#  'terms',
#  'price',
#  'worthiness',
#  'especially',
#  'hours',
#  'stall',
#  'items',
#  'usually',
#  'priced',
#  'sure',
#  'reg',
#  'prices',
#  'changed',
#  'kimly',
#  'coffeeshop',
#  'dim',
#  'sum',
#  'stores',
#  'quality',
#  'quite',
#  'maybe',
#  'little',
#  'less',
#  'regular',
#  'stores',
#  'still',
#  'close',
#  'note',
#  'items',
#  'smaller',
#  'portion',
#  'size',
#  'standard',
#  'retail',
#  'stores',
#  'porridge',
#  'chee',
#  'cheong',
#  'fan',
#  'however',
#  'terms',
#  'quality',
#  'would',
#  'give',
#  'depending',
#  'buy',
#  'quality',
#  'fluctuate',
#  'per',
#  'visit',
#  'partly',
#  'due',
#  'part',
#  'batch',
#  'get',
#  'especially',
#  ...]

# %%
with open('tokens.pkl', 'wb') as file:
    pickle.dump(tokens, file)

# %%
frequency = Counter(combined_reviews.iloc[0]['review_text_processed'])
print(frequency)
# Out:
# Counter({'indian': 10, 'options': 8, 'excellent': 6, 'vegetarian': 6, 'lunch': 5, 'tasty': 5, 'best': 4, 'drinks': 4, 'chicken': 4, 'masala': 4, 'quality': 4, 'veg': 3, 'super': 3, 'vibe': 3, 'reasonable': 3, 'high': 3, 'rice': 3, 'boat': 3, 'quay': 3, 'singapore': 3, 'work': 3, 'non': 2, 'set': 2, 'portion': 2, 'fast': 2, 'far': 2, 'better': 2, 'spicy': 2, 'naan': 2, 'must': 2, 'bar': 2, 'prices': 2, 'evening': 2, 'friends': 2, 'value': 2, 'money': 2, 'reasonably': 2, 'priced': 2, 'menu': 2, 'variety': 2, 'awesome': 2, 'specially': 2, 'lots': 2, 'well': 2, 'parking': 2, 'street': 2, 'get': 2, 'plate': 2, 'serve': 2, 'beer': 2, 'ever': 2, 'times': 2, 'snacks': 2, 'even': 2, 'hygiene': 2, 'tikka': 2, 'us': 2, 'price': 2, 'absolutely': 1, 'generous': 1, 'efficient': 1, 'redeemed': 1, 'mealpal': 1, 'qr': 1, 'code': 1, 'displayed': 1, 'prominently': 1, 'much': 1, 'curries': 1, 'less': 1, 'expected': 1, 'little': 1, 'say': 1, 'probably': 1, 'thin': 1, 'chewy': 1, 'light': 1, 'crispy': 1, 'finish': 1, 'packed': 1, 'pretty': 1, 'bistro': 1, 'ideal': 1, 'cbd': 1, 'meals': 1, 'make': 1, 'venue': 1, 'social': 1, 'gatherings': 1, 'p': 1, 'till': 1, 'midnight': 1, 'happy': 1, 'hours': 1, 'effect': 1, 'give': 1, 'idea': 1, 'march': 1, 'pint': 1, 'sapporo': 1, 'costs': 1, 'double': 1, 'enjoying': 1, 'sitting': 1, 'outside': 1, 'enjoyable': 1, 'temperature': 1, 'muggy': 1, 'ceiling': 1, 'fans': 1, 'cooler': 1, 'needed': 1, 'astound': 1, 'offered': 1, 'burgers': 1, 'pizza': 1, 'spaghetti': 1, 'nan': 1, 'typical': 1, 'melodies': 1, 'north': 1, 'meal': 1, 'smallish': 1, 'bit': 1, 'crammed': 1, 'seating': 1, 'tastes': 1, 'feel': 1, 'fulfilled': 1, 'plan': 1, 'reach': 1, 'early': 1, 'courteous': 1, 'highly': 1, 'recommended': 1, 'sgd': 1, 'number': 1, 'items': 1, 'chat': 1, 'etc': 1, 'roti': 1, 'sabzi': 1, 'choice': 1, 'drink': 1, 'took': 1, 'jaljira': 1, 'vegetable': 1, 'biryani': 1, 'rayta': 1, 'papad': 1, 'expensive': 1, 'alcoholic': 1, 'whisky': 1, 'wine': 1, 'especially': 1, 'ordered': 1, 'fried': 1, 'point': 1, 'right': 1, 'level': 1, 'spice': 1, 'grab': 1, 'ate': 1, 'three': 1, 'watch': 1, 'ipl': 1, 'playoff': 1, 'finals': 1, 'dishes': 1, 'favorite': 1, 'paani': 1, 'poori': 1, 'shots': 1, 'try': 1, 'alcohol': 1, 'always': 1, 'go': 1, 'enjoy': 1, 'r': 1, 'night': 1, 'tasting': 1, 'prompt': 1, 'location': 1, 'vibrant': 1, 'circular': 1, 'road': 1, 'speedy': 1, 'ales': 1, 'cost': 1, 'wise': 1, 'tried': 1, 'arrabita': 1, 'pasta': 1, 'paneer': 1, 'wrap': 1, 'vast': 1, 'size': 1, 'met': 1, 'owner': 1, 'hails': 1, 'india': 1, 'gave': 1, 'travelling': 1, 'shopping': 1, 'overall': 1, 'dinner': 1, 'restaurants': 1, 'seems': 1, 'considering': 1, 'places': 1, 'never': 1, 'faced': 1, 'disappointment': 1, 'despite': 1, 'visiting': 1, 'quite': 1, 'often': 1, 'kudos': 1, 'team': 1, 'running': 1, 'operating': 1, 'keep': 1, 'veggie': 1, 'nachos': 1, 'fries': 1, 'peanut': 1, 'favourites': 1, 'believe': 1, 'came': 1, 'last': 1, 'days': 1, 'leaving': 1, 'would': 1, 'recommend': 1, 'roghan': 1, 'gosh': 1, 'grilled': 1, 'salmon': 1, 'want': 1, 'name': 1, 'anyone': 1, 'since': 1, 'served': 1, 'hangout': 1, 'makes': 1, 'sure': 1, 'everyone': 1, 'gets': 1, 'love': 1, 'see': 1, 'someone': 1, 'enthusiastic': 1})

# %%
# Convert the Counter object to a dictionary for WordCloud
word_freq = dict(frequency)
# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate_from_frequencies(word_freq)
# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axes
plt.show()
